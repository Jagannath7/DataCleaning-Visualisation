# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/gapminder.csv') #tables are called dataframes

# %%
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 1699  Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country       1704 non-null object
# continent     1704 non-null object
# year          1704 non-null int64
# lifeExp       1704 non-null float64
# population    1704 non-null int64
# gdpPerCap     1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe() # for only numeric columns
# Out:
#              year      lifeExp    population      gdpPerCap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %% [markdown]
# ### Columns

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df.columns = ['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap']

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df.keys() # columns names are keys
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df[['country','lifeExp','gdpPerCap']].head()
# Out:
#        country  lifeExp   gdpPerCap
# 0  Afghanistan   28.801  779.445314
# 1  Afghanistan   30.332  820.853030
# 2  Afghanistan   31.997  853.100710
# 3  Afghanistan   34.020  836.197138
# 4  Afghanistan   36.088  739.981106

# %%
df.drop('continent',axis=1).head()
# Out:
#        country  year  lifeExp  population   gdpPerCap
# 0  Afghanistan  1952   28.801     8425333  779.445314
# 1  Afghanistan  1957   30.332     9240934  820.853030
# 2  Afghanistan  1962   31.997    10267083  853.100710
# 3  Afghanistan  1967   34.020    11537966  836.197138
# 4  Afghanistan  1972   36.088    13079460  739.981106

# %%
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %% [markdown]
# ### Rows

# %%
# loc = labels, iloc = indeces

# %%
df.iloc[700]
# Out:
# country           India
# continent          Asia
# year               1972
# lifeExp          50.651
# population    567000000
# gdpPerCap       724.033
# Name: 700, dtype: object

# %%
df.iloc[[1,10,100]]
# Out:
#          country continent  year  lifeExp  population   gdpPerCap
# 1    Afghanistan      Asia  1957   30.332     9240934  820.853030
# 10   Afghanistan      Asia  2002   42.129    25268405  726.734055
# 100   Bangladesh      Asia  1972   45.252    70759295  630.233627

# %%
df.loc[[1,10,100]]
# Out:
#          country continent  year  lifeExp  population   gdpPerCap
# 1    Afghanistan      Asia  1957   30.332     9240934  820.853030
# 10   Afghanistan      Asia  2002   42.129    25268405  726.734055
# 100   Bangladesh      Asia  1972   45.252    70759295  630.233627

# %%
df.iloc[-1]
# Out:
# country       Zimbabwe
# continent       Africa
# year              2007
# lifeExp         43.487
# population    12311143
# gdpPerCap      469.709
# Name: 1703, dtype: object

# %%
df.iloc[1:10]
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438    14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854    12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822    13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674    16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763    22227415  635.341351

# %%
df.loc[1:10]
# Out:
#         country continent  year  lifeExp  population   gdpPerCap
# 1   Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088    13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438    14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854    12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822    13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674    16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763    22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129    25268405  726.734055

# %%
df.iloc[1:5,1:4]
# Out:
#   continent  year  lifeExp
# 1      Asia  1957   30.332
# 2      Asia  1962   31.997
# 3      Asia  1967   34.020
# 4      Asia  1972   36.088

# %%
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.loc[1:5,'country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# 5    Afghanistan
# Name: country, dtype: object

# %%
df.iloc[[0,10,100],[0,2,4]]
# Out:
#          country  year  population
# 0    Afghanistan  1952     8425333
# 10   Afghanistan  2002    25268405
# 100   Bangladesh  1972    70759295

# %%
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %% [markdown]
# ### series - single row or column

# %%
r = df.loc[0]
type(r)
# Out:
# pandas.core.series.Series

# %%
le = df['lifeExp']
m = le.mean()
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %%
le[le > m]
# Out:
# 14      64.820
# 15      66.220
# 16      67.690
# 17      68.930
# 18      70.420
#          ...
# 1678    60.308
# 1679    62.698
# 1698    60.363
# 1699    62.351
# 1700    60.377
# Name: lifeExp, Length: 895, dtype: float64

# %%
df.loc[df.lifeExp>m].head()
# Out:
#     country continent  year  lifeExp  population    gdpPerCap
# 14  Albania    Europe  1962    64.82     1728137  2312.888958
# 15  Albania    Europe  1967    66.22     1984060  2760.196931
# 16  Albania    Europe  1972    67.69     2263554  3313.422188
# 17  Albania    Europe  1977    68.93     2509048  3533.003910
# 18  Albania    Europe  1982    70.42     2780097  3630.880722

# %%
df.loc[df.lifeExp >60, ['country','lifeExp']].head()
# Out:
#     country  lifeExp
# 14  Albania    64.82
# 15  Albania    66.22
# 16  Albania    67.69
# 17  Albania    68.93
# 18  Albania    70.42

# %%
df.loc[(df.lifeExp>60) & (df.lifeExp < 62),['country','continent']].head()
# Out:
#                     country continent
# 30                  Algeria    Africa
# 146  Bosnia and Herzegovina    Europe
# 162                Botswana    Africa
# 173                  Brazil  Americas
# 279                   Chile  Americas

# %%
df.loc[(df.lifeExp<30)|(df.lifeExp>65), ['year','lifeExp','country']].head()
# Out:
#     year  lifeExp      country
# 0   1952   28.801  Afghanistan
# 15  1967   66.220      Albania
# 16  1972   67.690      Albania
# 17  1977   68.930      Albania
# 18  1982   70.420      Albania

# %%
df.loc[df.country=='Zimbabwe']
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 1692  Zimbabwe    Africa  1952   48.451     3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469     3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358     4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995     4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635     5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674     6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363     7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143  469.709298

# %%
df.loc[(df.country >'Kenya')].head()
# Out:
#               country continent  year  lifeExp  population    gdpPerCap
# 828  Korea, Dem. Rep.      Asia  1952   50.056     8865488  1088.277758
# 829  Korea, Dem. Rep.      Asia  1957   54.081     9411381  1571.134655
# 830  Korea, Dem. Rep.      Asia  1962   56.656    10917494  1621.693598
# 831  Korea, Dem. Rep.      Asia  1967   59.942    12617009  2143.540609
# 832  Korea, Dem. Rep.      Asia  1972   63.983    14781241  3701.621503

# %% [markdown]
# ### grouping

# %%
df.groupby('year')['lifeExp','gdpPerCap'].mean().reset_index()
# Out:
#     year    lifeExp     gdpPerCap
# 0   1952  49.057620   3725.276046
# 1   1957  51.507401   4299.408345
# 2   1962  53.609249   4725.812342
# 3   1967  55.678290   5483.653047
# 4   1972  57.647386   6770.082815
# 5   1977  59.570157   7313.166421
# 6   1982  61.533197   7518.901673
# 7   1987  63.212613   7900.920218
# 8   1992  64.160338   8158.608521
# 9   1997  65.014676   9090.175363
# 10  2002  65.694923   9917.848365
# 11  2007  67.007423  11680.071820

# %%
df.groupby(['continent','year']).mean().reset_index()
# Out:
#    continent  year    lifeExp    population     gdpPerCap
# 0     Africa  1952  39.135500  4.570010e+06   1252.572466
# 1     Africa  1957  41.266346  5.093033e+06   1385.236062
# 2     Africa  1962  43.319442  5.702247e+06   1598.078825
# 3     Africa  1967  45.334538  6.447875e+06   2050.363801
# 4     Africa  1972  47.450942  7.305376e+06   2339.615674
# 5     Africa  1977  49.580423  8.328097e+06   2585.938508
# 6     Africa  1982  51.592865  9.602857e+06   2481.592960
# 7     Africa  1987  53.344788  1.105450e+07   2282.668991
# 8     Africa  1992  53.629577  1.267464e+07   2281.810333
# 9     Africa  1997  53.598269  1.430448e+07   2378.759555
# 10    Africa  2002  53.325231  1.603315e+07   2599.385159
# 11    Africa  2007  54.806038  1.787576e+07   3089.032605
# 12  Americas  1952  53.279840  1.380610e+07   4079.062552
# 13  Americas  1957  55.960280  1.547816e+07   4616.043733
# 14  Americas  1962  58.398760  1.733081e+07   4901.541870
# ...

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# ### sorting

# %%
df.sort_values(['year','lifeExp'],ascending=[1,0]).head()
# Out:
#           country continent  year  lifeExp  population     gdpPerCap
# 1140       Norway    Europe  1952    72.67     3327728  10095.421720
# 684       Iceland    Europe  1952    72.49      147962   7267.688428
# 1080  Netherlands    Europe  1952    72.13    10381988   8941.571858
# 1464       Sweden    Europe  1952    71.86     7124673   8527.844662
# 408       Denmark    Europe  1952    70.78     4334000   9692.385245

# %% [markdown]
# ### Concat

# %%
pd.Series([10,20,30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(['a','b','c'])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.DataFrame([[10,20],[30,40]], columns = ['A','B'])
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
pd.DataFrame({'A':[10,30],'B':[20,40]})
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
a = pd.DataFrame([[10,20],[30,40]],columns=['A','B'])

# %%
b = pd.DataFrame({'A':[50,70],'B':[60,80]})

# %%
pd.concat([a,b],axis=1)
# Out:
#     A   B   A   B
# 0  10  20  50  60
# 1  30  40  70  80
